# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 879.0/879.0 kB 28.2 MB/s eta 0:00:00
# ...

# %%
import yaml
import ultralytics
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
config_data = {
    'nc' : 1,
    'names' : ['car plate'],
    'train' : '/content/drive/MyDrive/Colab Notebooks/car_plate_egypt/Egypt_car_plates/train/images',
    'val' : '/content/drive/MyDrive/Colab Notebooks/car_plate_egypt/Egypt_car_plates/test/images'
}
file_path = '/content/yolo_config.yaml'
with open(file_path, 'w') as file:
    yaml.dump(config_data, file)

# %%
# !yolo task=detect  mode=train model=yolo11x.pt data='/content/yolo_config.yaml' epochs=100 imgsz=640 batch=8
# Out:
# Ultralytics 8.3.27 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
